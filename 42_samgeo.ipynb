# %% [markdown]
# # Semantic Segmentation with SAM and GeoAI
#
# [![image](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/opengeos/geoai/blob/main/docs/examples/samgeo.ipynb)
#
# ## Install package
# To use the `geoai-py` package, ensure it is installed in your environment. Uncomment the command below if needed.

# %%
# %pip install geoai-py

# %% [markdown]
# ## Import libraries

# %%
import geoai
from geoai.sam import SamGeo

# %% [markdown]
# ## Download sample data

# %%
url = (
    "https://huggingface.co/datasets/giswqs/geospatial/resolve/main/sam_demo_image.tif"
)
image = geoai.download_file(url)
# Out:
# Downloading sam_demo_image.tif: 100%|██████████| 3.43M/3.43M [00:00<00:00, 6.60MB/s]

# %% [markdown]
# ## Visualize data

# %%
geoai.view_raster(url)
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2addbe62002f7b6b3b36f85ea79a5c52 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/proj4@2.8.1/dist/proj4.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/georaster@1.6.0&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/georaster-layer-for-leaflet@4.1.2/dist/georaster-layer-for-leaflet.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2addbe62002f7b6b3b36f85ea79a5c52&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2addbe62002f7b6b3b36f85ea79a5c52 = L.map(
#                 &quot;map_2addbe62002f7b6b3b36f85ea79a5c52&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 2,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
#   &quot;drawExport&quot;: false,
#   &quot;layersControl&quot;: true,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_2addbe62002f7b6b3b36f85ea79a5c52);
#
#
#
#
#
#             var tile_layer_77cdc9b0c9c549edf16e8aa396ade564 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 24,
#   &quot;maxNativeZoom&quot;: 24,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_77cdc9b0c9c549edf16e8aa396ade564.addTo(map_2addbe62002f7b6b3b36f85ea79a5c52);
#
#
#             L.control.fullscreen(
#                 {
#   &quot;position&quot;: &quot;topleft&quot;,
#   &quot;title&quot;: &quot;Full Screen&quot;,
#   &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;,
#   &quot;forceSeparateButton&quot;: false,
# }
#             ).addTo(map_2addbe62002f7b6b3b36f85ea79a5c52);
#
#
#             map_2addbe62002f7b6b3b36f85ea79a5c52.fitBounds(
#                 [[20, 0], [20, 0]],
#                 {&quot;maxZoom&quot;: 2}
#             );
#
#
#             var macro_element_acd26250de0103c7b18b89591e7ebbb1 = L.layerGroup();
#
#             (function() {
#                 var layerName = &quot;Raster&quot;;
#                 if (true) {
#                     macro_element_acd26250de0103c7b18b89591e7ebbb1._layerControlName = layerName;
#                     map_2addbe62002f7b6b3b36f85ea79a5c52.layerControlEntries = map_2addbe62002f7b6b3b36f85ea79a5c52.layerControlEntries || [];
#                     map_2addbe62002f7b6b3b36f85ea79a5c52.layerControlEntries.push({ layer: macro_element_acd26250de0103c7b18b89591e7ebbb1, name: layerName });
#                 }
#             })();
#
#             (async function() {
#                 const waitForGeoRaster = (maxAttempts = 60, delay = 200) =&gt;
#                     new Promise((resolve, reject) =&gt; {
#                         let attempts = 0;
#                         const check = () =&gt; {
#                             if (window.parseGeoraster &amp;&amp; window.GeoRasterLayer) {
#                                 resolve();
#                             } else if (attempts &gt;= maxAttempts) {
#                                 reject(new Error(&quot;GeoRaster libraries failed to load&quot;));
#                             } else {
#                                 attempts += 1;
#                                 setTimeout(check, delay);
#                             }
#                         };
#                         check();
#                     });
#
#                 try {
#                     await waitForGeoRaster();
#                     const mapRef = map_2addbe62002f7b6b3b36f85ea79a5c52;
#                     const layerSequence = 1;
#
#                     // Create a custom pane for this GeoTIFF layer with explicit z-index
#                     const paneName = &#x27;geotiff-pane-&#x27; + layerSequence;
#                     if (!mapRef.getPane(paneName)) {
#                         const pane = mapRef.createPane(paneName);
#                         // Set z-index: 400 is default for overlays (vectors), use 300-399 range
#                         // for GeoTIFF layers so they appear below vector layers
#                         pane.style.zIndex = 300 + layerSequence;
#                     }
#
#                     const indexes = null;
#                     const georaster = await window.parseGeoraster(&quot;https://huggingface.co/datasets/giswqs/geospatial/resolve/main/sam_demo_image.tif&quot;);
#                     const palette = [];
#                     const hasPalette = Array.isArray(palette) &amp;&amp; palette.length &gt; 0;
#                     const nodataColor = null;
#                     const suppliedRange = null;
#                     const layerOptions = {&quot;name&quot;: &quot;Raster&quot;, &quot;opacity&quot;: 1.0, &quot;resolution&quot;: 128, &quot;zIndex&quot;: 501};
#                     layerOptions

# %% [markdown]
# ## Initialize model

# %%
sam = SamGeo(model="facebook/sam-vit-huge", automatic=True)
# Out:
# config.json: 0.00B [00:00, ?B/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# model.safetensors:   0%|          | 0.00/2.56G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/594 [00:00<?, ?it/s]
# preprocessor_config.json:   0%|          | 0.00/466 [00:00<?, ?B/s]

# %% [markdown]
# ## Automatic mask generation

# %%
sam.generate(source=image, output="masks.tif", foreground=True)
# Out:
# [ WARN:0@0.011] global grfmt_tiff.cpp:122 TIFF_Warning TIFFReadDirectory: Unknown field with tag 33550 (0x830e) encountered
# [ WARN:0@0.011] global grfmt_tiff.cpp:122 TIFF_Warning TIFFReadDirectory: Unknown field with tag 33922 (0x8482) encountered
# [ WARN:0@0.011] global grfmt_tiff.cpp:122 TIFF_Warning TIFFReadDirectory: Unknown field with tag 34735 (0x87af) encountered
# [ WARN:0@0.011] global grfmt_tiff.cpp:122 TIFF_Warning TIFFReadDirectory: Unknown field with tag 34737 (0x87b1) encountered
# [ WARN:0@0.011] global grfmt_tiff.cpp:122 TIFF_Warning TIFFReadDirectory: Unknown field with tag 42112 (0xa480) encountered
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 sam.generate(source=image, output="masks.tif", foreground=True)
#
# File ~/.local/lib/python3.11/site-packages/geoai/sam.py:168, in SamGeo.generate(self, source, output, foreground, erosion_kernel, mask_multiplier, unique, min_size, max_size, output_args, **kwargs)
#     166 formatted_masks = []
#     167 for mask, score in zip(masks, scores):
# --> 168     area = int(np.sum(mask))  # number of True pixels
#     169     formatted_masks.append(
#     170         {
#     171             "segmentation": mask,
#    (...)    174         }
#     175     )
#     177 self.output = result  # Store the result
#
# File ~/.local/lib/python3.11/site-packages/numpy/_core/fromnumeric.py:2425, in sum(a, axis, dtype, out, keepdims, initial, where)
#    2417 if isinstance(a, _gentype):
#    2418     # 2018-02-25, 1.15.0
#    2419     raise TypeError(
#    2420         "Calling np.sum(generator) is deprecated."
#    2421         "Use np.sum(np.fromiter(generator)) or "
#    2422         "the python sum builtin instead.",
#    2423     )
# -> 2425 return _wrapreduction(
#    2426     a, np.add, 'sum', axis, dtype, out,
#    2427     keepdims=keepdims, initial=initial, where=where
#    2428 )
#
# File ~/.local/lib/python3.11/site-packages/numpy/_core/fromnumeric.py:81, in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      79             return reduction(axis=axis, dtype=dtype, out=out, **passkwargs)
#      80         else:
# ---> 81             return reduction(axis=axis, out=out, **passkwargs)
#      83 return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#
# TypeError: sum() received an invalid combination of arguments - got (out=NoneType, axis=NoneType, ), but expected one of:
#  * (*, torch.dtype dtype = None)
#       didn't match because some of the keywords were incorrect: out, axis
#  * (tuple of ints dim, bool keepdim = False, *, torch.dtype dtype = None)
#  * (tuple of names dim, bool keepdim = False, *, torch.dtype dtype = None)

# %% [markdown]
# ## Visualize results

# %%
sam.show_masks()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 sam.show_masks()
#
# File ~/.local/lib/python3.11/site-packages/geoai/sam.py:415, in SamGeo.show_masks(self, figsize, cmap, axis, foreground, **kwargs)
#     412 import cv2  # Lazy import to avoid QGIS opencv conflicts
#     413 import matplotlib.pyplot as plt
# --> 415 if self.batch:
#     416     self.objects = cv2.imread(self.masks)
#     417 else:
#
# AttributeError: 'SamGeo' object has no attribute 'batch'

# %%
sam.show_anns(alpha=0.6)

# %%
geoai.view_raster("masks.tif", colormap="tab20", opacity=0.6, basemap=url)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 geoai.view_raster("masks.tif", colormap="tab20", opacity=0.6, basemap=url)
#
# File ~/.local/lib/python3.11/site-packages/geoai/utils/visualization.py:165, in view_raster(source, indexes, colormap, vmin, vmax, nodata, attribution, layer_name, layer_index, zoom_to_layer, visible, opacity, array_args, client_args, legend_args, basemap, basemap_args, backend, **kwargs)
#     156         m.add_cog_layer(
#     157             source,
#     158             name=layer_name,
#    (...)    162             **kwargs,
#     163         )
#     164 else:
# --> 165     m.add_raster(
#     166         source=source,
#     167         indexes=indexes,
#     168         colormap=colormap,
#     169         vmin=vmin,
#     170         vmax=vmax,
#     171         nodata=nodata,
#     172         attribution=attribution,
#     173         layer_name=layer_name,
#     174         layer_index=layer_index,
#     175         zoom_to_layer=zoom_to_layer,
#     176         visible=visible,
#     177         opacity=opacity,
#     178         array_args=array_args,
#     179         client_args=client_args,
#     180         **kwargs,
#     181     )
#     182 if isinstance(legend_args, dict):
#     183     m.add_legend(**legend_args)
#
# File ~/.local/lib/python3.11/site-packages/leafmap/foliumap.py:645, in Map.add_raster(self, source, indexes, colormap, vmin, vmax, nodata, attribution, layer_name, array_args, **kwargs)
#     642 if "google.colab" in sys.modules:
#     643     kwargs["cors_all"] = True
# --> 645 tile_layer, tile_client = common.get_local_tile_layer(
#     646     source,
#     647     indexes=indexes,
#     648     colormap=colormap,
#     649     vmin=vmin,
#     650     vmax=vmax,
#     651     nodata=nodata,
#     652     attribution=attribution,
#     653     tile_format="folium",
#     654     layer_name=layer_name,
#     655     return_client=True,
#     656     **kwargs,
#     657 )
#     658 self.add_layer(tile_layer)
#     660 bounds = tile_client.bounds()  # [ymin, ymax, xmin, xmax]
#
# File ~/.local/lib/python3.11/site-packages/leafmap/common.py:3427, in get_local_tile_layer(source, port, debug, indexes, colormap, vmin, vmax, nodata, attribution, tile_format, layer_name, client_args, return_client, quiet, **kwargs)
#    3413         tile_layer = get_leaflet_tile_layer(
#    3414             source,
#    3415             port=port,
#    (...)   3424             **kwargs,
#    3425         )
#    3426     else:
# -> 3427         tile_layer = get_folium_tile_layer(
#    3428             source,
#    3429             port=port,
#    3430             debug=debug,
#    3431             indexes=indexes,
#    3432             colormap=colormap,
#    3433             vmin=vmin,
#    3434             vmax=vmax,
#    3435             nodata=nodata,
#    3436             attr=attribution,
#    3437             overlay=True,
#    3438             name=layer_name,
#    3439             **kwargs,
#    3440         )
#    3442 if return_client:
#    3443     return tile_layer, tile_layer.tile_server
#
# File ~/.local/lib/python3.11/site-packages/localtileserver/widgets.py:210, in get_folium_tile_layer(source, port, debug, indexes, colormap, vmin, vmax, nodata, attr, **kwargs)
#     207 class FoliumTileLayer(TileLayer, LocalTileServerLayerMixin):
#     208     pass
# --> 210 source, created = get_or_create_tile_client(
#     211     source,
#     212     port=port,
#     213     debug=debug,
#     214 )
#     215 url = source.get_tile_url(
#     216     indexes=indexes,
#     217     colormap=colormap,
#    (...)    221     client=True,
#     222 )
#     223 if attr is None:
#
# File ~/.local/lib/python3.11/site-packages/localtileserver/client.py:590, in get_or_create_tile_client(source, port, debug)
#     588 # Launch tile server if file path is given
#     589 if not isinstance(source, TileClient):
# --> 590     source = TileClient(source, port=port, debug=debug)
#     591     _internally_created = True
#     593 # Check that the tile source is valid and no server errors
#
# File ~/.local/lib/python3.11/site-packages/localtileserver/client.py:560, in TileClient.__init__(self, source, port, debug, host, client_port, client_host, client_prefix, cors_all)
#     549 def __init__(
#     550     self,
#     551     source: pathlib.Path | str | rasterio.io.DatasetReaderBase,
#    (...)    558     cors_all: bool = False,
#     559 ):
# --> 560     TilerInterface.__init__(self, source=source)
#     561     TileServerMixin.__init__(
#     562         self,
#     563         port=port,
#    (...)    569         cors_all=cors_all,
#     570     )
#
# File ~/.local/lib/python3.11/site-packages/localtileserver/client.py:63, in TilerInterface.__init__(self, source)
#      61     self._reader = source
#      62 else:
# ---> 63     self._reader = get_reader(source)
#
# File ~/.local/lib/python3.11/site-packages/localtileserver/tiler/handler.py:24, in get_reader(path)
#      23 def get_reader(path: pathlib.Path | str) -> Reader:
# ---> 24     return Reader(get_clean_filename(path))
#
# File ~/.local/lib/python3.11/site-packages/localtileserver/tiler/utilities.py:101, in get_clean_filename(filename)
#      99 filename = pathlib.Path(filename).expanduser().absolute()
#     100 if not filename.exists():
# --> 101     raise OSError(f"Path does not exist: {filename}")
#     102 return filename
#
# OSError: Path does not exist: /home/openzeka/Desktop/mekansal-veri/masks.tif

# %%
geoai.create_split_map(
    left_layer="masks.tif",
    right_layer=url,
    left_args={
        "colormap": "tab20",
        "opacity": 1,
    },
)

# %% [markdown]
# ![image](https://github.com/user-attachments/assets/8735160b-efb3-4b3c-9b1f-f83188874585)
