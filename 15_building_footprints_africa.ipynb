# %% [markdown]
# # Building Footprint Extraction for Africa
#
# [![image](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/opengeos/geoai/blob/main/docs/examples/building_footprints_africa.ipynb)
#
# ## Install package
#
# To use the `geoai-py` package, ensure it is installed in your environment. Uncomment the command below if needed.

# %%
# %pip install geoai-py

# %% [markdown]
# ## Import libraries

# %%
import geoai

# %% [markdown]
# ## Download sample data

# %%
raster_url = "https://huggingface.co/datasets/giswqs/geospatial/resolve/main/buildings_africa.tif"

# %%
raster_path = geoai.download_file(raster_url)
# Out:
# Downloading buildings_africa.tif: 100%|██████████| 13.9M/13.9M [00:00<00:00, 63.3MB/s]

# %% [markdown]
# ## Initialize the model

# %%
extractor = geoai.BuildingFootprintExtractor(model_path="building_footprints_usa.pth")
# Out:
# building_footprints_usa.pth:   0%|          | 0.00/176M [00:00<?, ?B/s]

# %% [markdown]
# ## Extract building footprints

# %%
masks_path = extractor.generate_masks(
    raster_path,
    output_dir="building_masks.tif",
    min_object_area=1000,
    confidence_threshold=0.5,
    threshold=0.5,
)
# Out:
# 100%|██████████| 9/9 [00:03<00:00,  2.70it/s]

# %%
geoai.view_raster(masks_path, opacity=0.7, colormap="tab20", basemap=raster_url)
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bcaa68409aa2014276b9232cd13a3079 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/proj4@2.8.1/dist/proj4.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/georaster@1.6.0&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/georaster-layer-for-leaflet@4.1.2/dist/georaster-layer-for-leaflet.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bcaa68409aa2014276b9232cd13a3079&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bcaa68409aa2014276b9232cd13a3079 = L.map(
#                 &quot;map_bcaa68409aa2014276b9232cd13a3079&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 2,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
#   &quot;drawExport&quot;: false,
#   &quot;layersControl&quot;: true,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_bcaa68409aa2014276b9232cd13a3079);
#
#
#
#
#
#             var tile_layer_15da74357836f1b72cceeabcbb47f34b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 24,
#   &quot;maxNativeZoom&quot;: 24,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_15da74357836f1b72cceeabcbb47f34b.addTo(map_bcaa68409aa2014276b9232cd13a3079);
#
#
#             L.control.fullscreen(
#                 {
#   &quot;position&quot;: &quot;topleft&quot;,
#   &quot;title&quot;: &quot;Full Screen&quot;,
#   &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;,
#   &quot;forceSeparateButton&quot;: false,
# }
#             ).addTo(map_bcaa68409aa2014276b9232cd13a3079);
#
#
#             map_bcaa68409aa2014276b9232cd13a3079.fitBounds(
#                 [[20, 0], [20, 0]],
#                 {&quot;maxZoom&quot;: 2}
#             );
#
#
#             var macro_element_84ef652d8bb1d03c947d94c86791f97b = L.layerGroup();
#
#             (function() {
#                 var layerName = &quot;Basemap&quot;;
#                 if (true) {
#                     macro_element_84ef652d8bb1d03c947d94c86791f97b._layerControlName = layerName;
#                     map_bcaa68409aa2014276b9232cd13a3079.layerControlEntries = map_bcaa68409aa2014276b9232cd13a3079.layerControlEntries || [];
#                     map_bcaa68409aa2014276b9232cd13a3079.layerControlEntries.push({ layer: macro_element_84ef652d8bb1d03c947d94c86791f97b, name: layerName });
#                 }
#             })();
#
#             (async function() {
#                 const waitForGeoRaster = (maxAttempts = 60, delay = 200) =&gt;
#                     new Promise((resolve, reject) =&gt; {
#                         let attempts = 0;
#                         const check = () =&gt; {
#                             if (window.parseGeoraster &amp;&amp; window.GeoRasterLayer) {
#                                 resolve();
#                             } else if (attempts &gt;= maxAttempts) {
#                                 reject(new Error(&quot;GeoRaster libraries failed to load&quot;));
#                             } else {
#                                 attempts += 1;
#                                 setTimeout(check, delay);
#                             }
#                         };
#                         check();
#                     });
#
#                 try {
#                     await waitForGeoRaster();
#                     const mapRef = map_bcaa68409aa2014276b9232cd13a3079;
#                     const layerSequence = 1;
#
#                     // Create a custom pane for this GeoTIFF layer with explicit z-index
#                     const paneName = &#x27;geotiff-pane-&#x27; + layerSequence;
#                     if (!mapRef.getPane(paneName)) {
#                         const pane = mapRef.createPane(paneName);
#                         // Set z-index: 400 is default for overlays (vectors), use 300-399 range
#                         // for GeoTIFF layers so they appear below vector layers
#                         pane.style.zIndex = 300 + layerSequence;
#                     }
#
#                     const indexes = null;
#                     const georaster = await window.parseGeoraster(&quot;https://huggingface.co/datasets/giswqs/geospatial/resolve/main/buildings_africa.tif&quot;);
#                     const palette = [];
#                     const hasPalette = Array.isArray(palette) &amp;&amp; palette.length &gt; 0;
#                     const nodataColor = null;
#                     const suppliedRange = null;
#                     const layerOptions = {&quot;attribution&quot;: &quot;.&quot;, &quot;name&quot;: &quot;Basemap&quot;, &quot;opacity&quot;: 1.0, &quot;resolution&quot;: 128, &quot;zIndex&q

# %% [markdown]
# ## Vectorize masks

# %%
gdf = geoai.orthogonalize(
    input_path=masks_path, output_path="building_footprints.geojson", epsilon=1.0
)
# Out:
# Converting features: 100%|██████████| 233/233 [00:01<00:00, 134.04shape/s]

# %% [markdown]
# ## Add geometric attributes

# %%
gdf = geoai.add_geometric_properties(gdf)

# %% [markdown]
# ## Visualize results

# %%
geoai.view_vector_interactive(
    gdf, style_kwds={"color": "red", "fillOpacity": 0.2}, tiles=raster_url
)
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e47300b1e4dff5fcf957c02b558f0d83 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/proj4@2.8.1/dist/proj4.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/georaster@1.6.0&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/georaster-layer-for-leaflet@4.1.2/dist/georaster-layer-for-leaflet.min.js&quot;&gt;&lt;/script&gt;
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e47300b1e4dff5fcf957c02b558f0d83&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e47300b1e4dff5fcf957c02b558f0d83 = L.map(
#                 &quot;map_e47300b1e4dff5fcf957c02b558f0d83&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 2,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
#   &quot;drawExport&quot;: false,
#   &quot;layersControl&quot;: true,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_e47300b1e4dff5fcf957c02b558f0d83);
#
#
#
#
#
#             var tile_layer_0fad1e0efcc46c57c045e5586cf6ac87 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 24,
#   &quot;maxNativeZoom&quot;: 24,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0fad1e0efcc46c57c045e5586cf6ac87.addTo(map_e47300b1e4dff5fcf957c02b558f0d83);
#
#
#             L.control.fullscreen(
#                 {
#   &quot;position&quot;: &quot;topleft&quot;,
#   &quot;title&quot;: &quot;Full Screen&quot;,
#   &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;,
#   &quot;forceSeparateButton&quot;: false,
# }
#             ).addTo(map_e47300b1e4dff5fcf957c02b558f0d83);
#
#
#             map_e47300b1e4dff5fcf957c02b558f0d83.fitBounds(
#                 [[20, 0], [20, 0]],
#                 {&quot;maxZoom&quot;: 2}
#             );
#
#
#             var macro_element_a7b77fe015818f7aee0d019dc0cddef1 = L.layerGroup();
#
#             (function() {
#                 var layerName = &quot;Remote Raster&quot;;
#                 if (true) {
#                     macro_element_a7b77fe015818f7aee0d019dc0cddef1._layerControlName = layerName;
#                     map_e47300b1e4dff5fcf957c02b558f0d83.layerControlEntries = map_e47300b1e4dff5fcf957c02b558f0d83.layerControlEntries || [];
#                     map_e47300b1e4dff5fcf957c02b558f0d83.layerControlEntries.push({ layer: macro_element_a7b77fe015818f7aee0d019dc0cddef1, name: layerName });
#                 }
#             })();
#
#             (async function() {
#                 const waitForGeoRaster = (maxAttempts = 60, delay = 200) =&gt;
#                     new Promise((resolve, reject) =&gt; {
#                         let attempts = 0;
#                         const check = () =&gt; {
#                             if (window.parseGeoraster &amp;&amp; window.GeoRasterLayer) {
#                                 resolve();
#                             } else if (attempts &gt;= maxAttempts) {
#                                 reject(new Error(&quot;GeoRaster libraries failed to load&quot;));
#                             } else {
#                                 attempts += 1;
#                                 setTimeout(check, delay);
#                             }
#                         };
#                         check();
#                     });
#
#                 try {
#                     await waitForGeoRaster();
#                     const mapRef = map_e47300b1e4dff5fcf957c02b558f0d83;
#                     const layerSequence = 1;
#
#                     // Create a custom pane for this GeoTIFF layer with explicit z-index
#                     const paneName = &#x27;geotiff-pane-&#x27; + layerSequence;
#                     if (!mapRef.getPane(paneName)) {
#                         const pane = mapRef.createPane(paneName);
#                         // Set z-index: 400 is default for overlays (vectors), use 300-399 range
#                         // for GeoTIFF layers so they appear below vector layers
#                         pane.style.zIndex = 300 + layerSequence;
#                     }
#
#                     const indexes = null;
#                     const georaster

# %% [markdown]
# ![image](https://github.com/user-attachments/assets/8c651e7d-b2c3-4bb4-871e-4317cd1444a1)
