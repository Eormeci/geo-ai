# %% [markdown]
# # Download Sentinel-2 Data from Planetary Computer
#
# [![image](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/opengeos/geoai/blob/main/docs/examples/download_sentinel2.ipynb)
#
# The notebook demonstrates how to download Sentinel-2 data from the [Planetary Computer](https://planetarycomputer.microsoft.com/explore) using the `geoai` package.
#
# ## Install package
# To use the `geoai-py` package, ensure it is installed in your environment. Uncomment the command below if needed.

# %%
# %pip install geoai-py

# %% [markdown]
# ## Import libraries

# %%
import geoai

# %% [markdown]
# ## Search data
#
# Go to the [Planetary Computer](https://planetarycomputer.microsoft.com/explore) and search for the data you are interested in. Copy the STAC item link and paste it to the code below.

# %%
# Example for Sentinel-2 item
item_url = "https://planetarycomputer.microsoft.com/api/stac/v1/collections/sentinel-2-l2a/items/S2B_MSIL2A_20250228T173149_R055_T14SLH_20250228T212633"

# %% [markdown]
# ## Download sample data

# %%
# Specify which bands to download (Sentinel-2 bands)
bands_to_download = [
    "B01",
    "B02",
    "B03",
    "B04",
    "B05",
    "B06",
    "B07",
    "B08",
    "B8A",
    "B09",
    "B11",
    "B12",
    "AOT",
    "WVP",
    "SCL",
]

# %%
# Create a directory for the downloaded bands
output_directory = "sentinel2_bands"

# %%
# Download the bands, save them to the output directory, and create a merged GeoTIFF.
# The download process may take a while. Please be patient.
downloaded_bands = geoai.download_pc_stac_item(
    item_url=item_url,
    bands=bands_to_download,
    output_dir=output_directory,
    show_progress=True,
    merge_bands=True,
    merged_filename="sentinel2_all_bands.tif",
    overwrite=False,  # Skip files that already exist
    cell_size=10,  # Resample all bands to 10m resolution
)
# Out:
# /home/openzeka/.local/lib/python3.11/site-packages/pystac_client/item_search.py:925: FutureWarning: get_items() is deprecated, use items() instead
#   warnings.warn(
# Downloading B05:   0%|          | 0/15 [00:00<?, ?it/s]
# File sentinel2_bands/S2B_MSIL2A_20250228T173149_R055_T14SLH_20250228T212633_B01.tif already exists, skipping (use overwrite=True to force download).
# File sentinel2_bands/S2B_MSIL2A_20250228T173149_R055_T14SLH_20250228T212633_B02.tif already exists, skipping (use overwrite=True to force download).
# File sentinel2_bands/S2B_MSIL2A_20250228T173149_R055_T14SLH_20250228T212633_B03.tif already exists, skipping (use overwrite=True to force download).
# File sentinel2_bands/S2B_MSIL2A_20250228T173149_R055_T14SLH_20250228T212633_B04.tif already exists, skipping (use overwrite=True to force download).
# Downloading SCL: 100%|██████████| 15/15 [01:58<00:00,  7.93s/it]

# %%
# Print the paths to the downloaded files
for band, path in downloaded_bands.items():
    print(f"Downloaded {band}: {path}")
# Out:
# Downloaded B01: sentinel2_bands/S2B_MSIL2A_20250228T173149_R055_T14SLH_20250228T212633_B01.tif
# Downloaded B02: sentinel2_bands/S2B_MSIL2A_20250228T173149_R055_T14SLH_20250228T212633_B02.tif
# Downloaded B03: sentinel2_bands/S2B_MSIL2A_20250228T173149_R055_T14SLH_20250228T212633_B03.tif
# Downloaded B04: sentinel2_bands/S2B_MSIL2A_20250228T173149_R055_T14SLH_20250228T212633_B04.tif
# Downloaded B05: sentinel2_bands/S2B_MSIL2A_20250228T173149_R055_T14SLH_20250228T212633_B05.tif
# Downloaded B06: sentinel2_bands/S2B_MSIL2A_20250228T173149_R055_T14SLH_20250228T212633_B06.tif
# Downloaded B07: sentinel2_bands/S2B_MSIL2A_20250228T173149_R055_T14SLH_20250228T212633_B07.tif
# Downloaded B08: sentinel2_bands/S2B_MSIL2A_20250228T173149_R055_T14SLH_20250228T212633_B08.tif
# Downloaded B8A: sentinel2_bands/S2B_MSIL2A_20250228T173149_R055_T14SLH_20250228T212633_B8A.tif
# Downloaded B09: sentinel2_bands/S2B_MSIL2A_20250228T173149_R055_T14SLH_20250228T212633_B09.tif
# Downloaded B11: sentinel2_bands/S2B_MSIL2A_20250228T173149_R055_T14SLH_20250228T212633_B11.tif
# Downloaded B12: sentinel2_bands/S2B_MSIL2A_20250228T173149_R055_T14SLH_20250228T212633_B12.tif
# Downloaded AOT: sentinel2_bands/S2B_MSIL2A_20250228T173149_R055_T14SLH_20250228T212633_AOT.tif
# Downloaded WVP: sentinel2_bands/S2B_MSIL2A_20250228T173149_R055_T14SLH_20250228T212633_WVP.tif
# Downloaded SCL: sentinel2_bands/S2B_MSIL2A_20250228T173149_R055_T14SLH_20250228T212633_SCL.tif
# Downloaded merged: sentinel2_bands/sentinel2_all_bands.tif

# %% [markdown]
# ## Visualize data

# %%
raster_url = "https://huggingface.co/datasets/giswqs/geospatial/resolve/main/sentinel2a_kansas.tif"

# %%
geoai.view_raster(raster_url, bidx=[8, 4, 3], rescale="1000,4000")
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f9f96774faf0b6927fd365725e9169a5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/proj4@2.8.1/dist/proj4.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/georaster@1.6.0&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/georaster-layer-for-leaflet@4.1.2/dist/georaster-layer-for-leaflet.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f9f96774faf0b6927fd365725e9169a5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f9f96774faf0b6927fd365725e9169a5 = L.map(
#                 &quot;map_f9f96774faf0b6927fd365725e9169a5&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 2,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
#   &quot;drawExport&quot;: false,
#   &quot;layersControl&quot;: true,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_f9f96774faf0b6927fd365725e9169a5);
#
#
#
#
#
#             var tile_layer_5ad8c2aa52ef54db6c4d51ced603cbbc = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 24,
#   &quot;maxNativeZoom&quot;: 24,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5ad8c2aa52ef54db6c4d51ced603cbbc.addTo(map_f9f96774faf0b6927fd365725e9169a5);
#
#
#             L.control.fullscreen(
#                 {
#   &quot;position&quot;: &quot;topleft&quot;,
#   &quot;title&quot;: &quot;Full Screen&quot;,
#   &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;,
#   &quot;forceSeparateButton&quot;: false,
# }
#             ).addTo(map_f9f96774faf0b6927fd365725e9169a5);
#
#
#             map_f9f96774faf0b6927fd365725e9169a5.fitBounds(
#                 [[20, 0], [20, 0]],
#                 {&quot;maxZoom&quot;: 2}
#             );
#
#
#             var macro_element_815de4d224fe7b18836efbb38e6fb5fe = L.layerGroup();
#
#             (function() {
#                 var layerName = &quot;Raster&quot;;
#                 if (true) {
#                     macro_element_815de4d224fe7b18836efbb38e6fb5fe._layerControlName = layerName;
#                     map_f9f96774faf0b6927fd365725e9169a5.layerControlEntries = map_f9f96774faf0b6927fd365725e9169a5.layerControlEntries || [];
#                     map_f9f96774faf0b6927fd365725e9169a5.layerControlEntries.push({ layer: macro_element_815de4d224fe7b18836efbb38e6fb5fe, name: layerName });
#                 }
#             })();
#
#             (async function() {
#                 const waitForGeoRaster = (maxAttempts = 60, delay = 200) =&gt;
#                     new Promise((resolve, reject) =&gt; {
#                         let attempts = 0;
#                         const check = () =&gt; {
#                             if (window.parseGeoraster &amp;&amp; window.GeoRasterLayer) {
#                                 resolve();
#                             } else if (attempts &gt;= maxAttempts) {
#                                 reject(new Error(&quot;GeoRaster libraries failed to load&quot;));
#                             } else {
#                                 attempts += 1;
#                                 setTimeout(check, delay);
#                             }
#                         };
#                         check();
#                     });
#
#                 try {
#                     await waitForGeoRaster();
#                     const mapRef = map_f9f96774faf0b6927fd365725e9169a5;
#                     const layerSequence = 1;
#
#                     // Create a custom pane for this GeoTIFF layer with explicit z-index
#                     const paneName = &#x27;geotiff-pane-&#x27; + layerSequence;
#                     if (!mapRef.getPane(paneName)) {
#                         const pane = mapRef.createPane(paneName);
#                         // Set z-index: 400 is default for overlays (vectors), use 300-399 range
#                         // for GeoTIFF layers so they appear below vector layers
#                         pane.style.zIndex = 300 + layerSequence;
#                     }
#
#                     const indexes = [8, 4, 3];
#                     const georaster = await window.parseGeoraster(&quot;https://huggingface.co/datasets/giswqs/geospatial/resolve/main/sentinel2a_kansas.tif&quot;);
#                     const palette = [];
#                     const hasPalette = Array.isArray(palette) &amp;&amp; palette.length &gt; 0;
#                     const nodataColor = null;
#                     const suppliedRange = [1000.0, 4000.0];
#                     const layerOptions = {&quot;name&quot;: &quot;Raster&quot;, &quot;opacity&quot;: 1.0, &quot;resolution&quot;: 128, &quot;zIndex&quot;: 501};
