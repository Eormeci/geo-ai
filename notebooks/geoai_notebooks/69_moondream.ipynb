# %% [markdown]
# # Geospatial Image Analysis with Moondream Vision Language Model
#
# [![image](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/opengeos/geoai/blob/main/docs/examples/moondream.ipynb)
#
# This notebook demonstrates how to use the [Moondream](https://moondream.ai) vision language model for geospatial image analysis. Moondream is a small but powerful vision language model that can:
#
# - **Caption**: Generate descriptions of satellite/aerial imagery
# - **Query**: Answer questions about image content
# - **Detect**: Locate objects with bounding boxes
# - **Point**: Find specific objects and return their coordinates
#
# The GeoAI integration adds support for GeoTIFF files with automatic georeferencing of outputs.

# %% [markdown]
# ## Install packages
#
# Uncomment the following line to install the required packages.

# %%
# %pip install -U geoai-py

# %% [markdown]
# ## Import libraries

# %%
import leafmap
from geoai import MoondreamGeo
import geoai

# %% [markdown]
# ## Download sample data
#
# We'll use a sample GeoTIFF image of a parking lot with buildings and vegetation.

# %%
url = "https://huggingface.co/datasets/giswqs/geospatial/resolve/main/parking_lot.tif"
image_path = geoai.download_file(url)
image_path
# Out:
# Downloading parking_lot.tif: 100%|██████████| 4.46M/4.46M [00:00<00:00, 10.7MB/s]
# 'parking_lot.tif'

# %% [markdown]
# ## Visualize the image
#
# Let's first visualize the sample image on an interactive map.

# %%
m = leafmap.Map()
m.add_raster(image_path, layer_name="Satellite Image")
m
# Out:
# Map(center=[29.678521500000002, -95.42043100000001], controls=(ZoomControl(options=['position', 'zoom_in_text'…

# %% [markdown]
# ## Initialize the Moondream processor
#
# Load the Moondream2 model. The first time you run this, the model will be downloaded from HuggingFace (~3.7GB).
#
# **Note**: For reproducibility, we specify a specific model revision date.

# %%
processor = MoondreamGeo(
    model_name="vikhyatk/moondream2", revision="2025-06-21", device="cuda"
)
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/277 [00:00<?, ?B/s]
# hf_moondream.py: 0.00B [00:00, ?B/s]
# moondream.py: 0.00B [00:00, ?B/s]
# text.py: 0.00B [00:00, ?B/s]
# config.py: 0.00B [00:00, ?B/s]
# rope.py: 0.00B [00:00, ?B/s]
# layers.py: 0.00B [00:00, ?B/s]
# lora.py: 0.00B [00:00, ?B/s]
# vision.py: 0.00B [00:00, ?B/s]
# image_crops.py: 0.00B [00:00, ?B/s]
# region.py: 0.00B [00:00, ?B/s]
# utils.py: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/3.85G [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Loading weights:   0%|          | 0/592 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/592 [00:00<?, ?it/s]

# %% [markdown]
# ## Image Captioning
#
# Generate a description of the satellite image. The `length` parameter controls the detail level: "short", "normal", or "long".

# %%
result = processor.caption(image_path, length="normal")
print(result["caption"])
# Out:
#  Aristidentallyiously imp " wa Aust McKin jeden wildlyidentally bleibt Palest " non Greg PIN unmittelbar# # toujours ventricle imp Palest " nonPerm# # j in range(identallylywood wa Palest triumph wa Pleistocene# ## # Suzquel Palest imp Aust non PIN dimlyanteedidentally Shelley Palest Palest triumph wa QU looking for# # toujours ventricle Palest " spat touristertain ent wa " non unmittelbar weakly with intricate toujours weakly Palest " wa imp PIN commonly used dimlyidentally toujours imp imp " imp QU labours toujours toujours toujours " Palest non Mir PIN functions for toujourslich pelvis Palest imp wa wa Magistrate Judgematrix genuinelyidentally toujours imp imp ent imp PIN most likely dimly toujours toujours " Palest " imp PIN361 int) ->identally McKin " spare triumph mirror Palest].append dimlyidentally pleadings imp " spat Aust PIN��anteedidentally toujours imp imp mirror nonrist labours psychoidentally toujours imp " non imp PIN BraunGamma Mendidentally " "corner spat client monarchs with intricateSynt toujours Palest Palest Elizabeth imp McKin weakly diminishesidentally toujours Palest Palest " imp ** weakly diminishes Organe toujours Palest " wa Aust McKin laboursidentally toujours toujours Palest " non imp PIN weakly unambiguous toujours toujours impoubled toujours pelvis# #modify toujours " Palest Aust Palest toujoursrix# # toujours toujours wa Palest Elizabeth prospectriel# Print unambiguousidentally toujours Palest Palest triumph Palestrison# Print# # DataFrame toujours " Palest triumph Palest# ## ## Printidentally toujours Palest " spat Palestiven# ## # functions for toujours Palest Melbourne Aust Palestrisonflatten# #identally toujoursALLY " ent Austortun dimlyicipidentally toujours imp Palest triumph imp pelvis# #avedidentally barbarians Palest Palest " imp encoura don't knowMargGammaidentally " " non imp pelvisicipMarg McKinmaint spare Palest " imp pelvis# ## # toujours toujours imp impocent imprison don't know��lywood functions for Palest " non imp Magistrate Judge don't know��identally toujours " Palest " imp pelvis pelvis int) ->identally toujours Palest " non imp pelvisricia don't knowidentally toujours Palest " spat imp pelvis don't know# # toujours McKinALLY Palest imp imp pelvis reference to# Print toujours Bund Palest " spat Palest pelvis NGO Mendidentally pelvis Palest " ent imp pelvis# ## # toujours McKinALLY Palest " imp# #Marg# # toujours Hang imp Palest Elizabeth impropolitan scheint# # toujours Bund Palest " ent imp# # scheint# Print toujours McKin Palest " ent imp# # don't knowikes toujoursidentally Palest " ent imp# #rix scheint toujoursmoves Palest " non imp toujoursicip# # Mend monarchs imp imp " impivenumatic# # toujours McKin " Palest Elizabeth Palestriel pelvisrixidentally toujours ent Palest triumph impidden scheint don't know toujours McKin " Palest spat Palestriel# Print ChamberlainGammaissima Palest " non imprielgenerallyMargGamma toujours ent Palest MP Palest diaphragmcedentoma " imp Magistrate Judgeimental pelvis palm treesmaint Palest QU triumph imp# # an example McKin toujourslywoodoma OR triumph Aust Wariftimental toujoursmaint Palest Elizabeth perpet wa pelvis dimly# #Gamma toujours Palest Elizabeth EEOC imp# #aramiki++++maint       omin non imp a generalropolitanicip toujours(matrix Palest "agog# ## Printif __name__ == '__maincedent Palest Elizabeth triumph imp Magistrate Judgeicip# Print palindrommaint Palest Elizabeth mirror PalestristwickMargmethuablyoma PAR triumph imp# ## #icipalsemaint           oma "<<# # toujoursdisks " Hinterleib Palestwick# # Gloucester Mongols Palest Elizabeth non Austaret��# # Likmaintoma QU ded Palestaret# # unambiguousidentallymaint            returnoma perpet imp pelvis unimportant# # Lik diaphragmcedent non spat Austapore toujours# # pelvismaint Palestoma prospect Palestellectualgenerally# # pelvis toujours Elizabeth Palest triumph Austrivrick# # Mongols ventricle Palestoma triumph Austresents# ## # Commer ventric Elizabeth Palest " impellectual# P ...

# %% [markdown]
# ## Visual Question Answering
#
# Ask questions about the image content and get natural language answers.

# %%
result = processor.query("How many buildings are in the image?", image_path)
print(result["answer"])
# Out:
#  verdant wide range ofRI OK "<< Crete tre gelang verdant pedunRI
#  NGO{{ gemacht sedimentary user_input verdant Dorothy======== pelvis NGO

# %%
result = processor.query("What are the building roof colors?", image_path)
print(result["answer"])
# Out:
# Navcedent Dorothyistocene~ STRysmcedentcedentcedentcedent consolidated IPCCplay_ysm[]cedentcedentcedentcedent copyrandint pelvisduced premiers t-shirtistocenecedentcedent Palest pelvisunistysm alloccedentcedentcedentcedent Dorothy Franks Professor thermodynamicsastypecedentcedentcedentcedent overl�EMastype Mengecedentcedentcedent dear# # Kernecedentcedentcedentdehyde� OKrarypitecedentcedentcedentcedent choice == ========
# astype OK Computecedentcedentcedent choice == � Pomperary alloccedentcedentcedentcedent Dorothy BAS

# %% [markdown]
# ## Object Detection
#
# Detect objects and get bounding boxes. Results are automatically georeferenced when using GeoTIFF input.
#
# ### Detect buildings

# %%
result = processor.detect(image_path, "building", output_path="buildings.geojson")
print(f"Detected {len(result['objects'])} buildings")
# Out:
# Detected 18 buildings

# %% [markdown]
# View the GeoDataFrame with georeferenced bounding boxes:

# %%
result["gdf"]
# Out:
#        x_min     y_min     x_max     y_max  px_x_min  px_y_min  px_x_max  \
# 0   0.448344  0.215749  0.528218  0.374095       743       202       876
# 1   0.426531  0.401775  0.495344  0.520100       707       376       821
# 2   0.398696  0.387798  0.480210  0.467671       661       363       796
# 3   0.426073  0.378835  0.489943  0.537181       706       355       812
# 4   0.425348  0.413494  0.519965  0.531819       705       387       862
# 5   0.447524  0.384868  0.529038  0.464741       742       361       877
# 6   0.426073  0.378835  0.489943  0.537181       706       355       812
# 7   0.425348  0.413494  0.519965  0.531819       705       387       862
# 8   0.447524  0.389850  0.529038  0.444134       742       365       877
# 9   0.426073  0.378835  0.489943  0.537181       706       355       812
# 10  0.410699  0.413494  0.505316  0.531819       681       387       838
# 11  0.447524  0.406467  0.529038  0.449002       742       381       877
# 12  0.254985  0.378835  0.334859  0.537181       423       355       555
# 13  0.425348  0.413494  0.519965  0.531819       705       387       862
# 14  0.426040  0.387798  0.507554  0.467671       706       363       842
# 15  0.418071  0.381764  0.497945  0.540111       693       358       826
# 16  0.425348  0.413494  0.519965  0.531819       705       387       862
# 17  0.439712  0.378463  0.521226  0.477006       729       354       864
#
#     px_y_max                                           geometry
# 0        350  POLYGON ((-10622146.816 3462310.971, -10622146...
# 1        487  POLYGON ((-10622154.958 3462290.522, -10622154...
# 2        438  POLYGON ((-10622158.706 3462297.865, -10622158...
# 3        503  POLYGON ((-10622156.295 3462288.129, -10622156...
# 4        498  POLYGON ((-10622148.86 3462288.88, -10622148.8...
# 5        435  POLYGON ((-10622146.613 3462298.275, -10622146...
# 6        503  POLYGON ((-10622156.295 3462288.129, -10622156...
# 7        498  POLYGON ((-10622148.86 3462288.88, -10622148.8...
# 8        416  POLYGON ((-10622146.613 3462301.162, -10622146...
# 9        503  POLYGON ((-10622156.295 3462288.129, -10622156...
# 10       498  POLYGON ((-10622152.488 3462288.88, -10622152....
# 11       421  POLYGON ((-10622146.613 3462300.48, -10622146....
# 12       503  POLYGON ((-10622194.703 3462288.129, -10622194...
# 13       498  POLYGON ((-10622148.86 3462288.88, -10622148.8...
# 14       438  POLYGON ((-10622151.934 3462297.865, -10622151...
# 15       506  POLYGON ((-10622154.314 3462287.719, -10622154...
# 16       498  POLYGON ((-10622148.86 3462288.88, -10622148.8...
# 17       447  POLYGON ((-10622148.548 3462296.557, -10622148...

# %% [markdown]
# Add the detected buildings to the map:

# %%
m.add_gdf(result["gdf"], layer_name="buildings")
m
# Out:
# Map(bottom=867914.0, center=[29.645393033250706, -95.33042907714845], controls=(ZoomControl(options=['position…

# %% [markdown]
# ## Point Localization
#
# Find object center points instead of bounding boxes. Useful for counting and locating objects.
#
# ### Find building centroids

# %%
result = processor.point(
    image_path, "building", output_path="building_centroids.geojson"
)
print(f"Found {len(result['points'])} building centroids")
# Out:
# Found 1 building centroids

# %%
m.add_gdf(result["gdf"], layer_name="building_centroids")

# %% [markdown]
# ### Detect trees

# %%
result = processor.detect(image_path, "tree", output_path="trees.geojson")
print(f"Detected {len(result['objects'])} trees")
# Out:
# Detected 6 trees

# %%
m.add_gdf(result["gdf"], layer_name="trees")

# %% [markdown]
# ### Find tree centroids

# %%
result = processor.point(image_path, "trees", output_path="tree_centroids.geojson")
print(f"Found {len(result['points'])} tree centroids")
# Out:
# Found 4 tree centroids

# %%
m.add_gdf(result["gdf"], layer_name="tree_centroids")

# %% [markdown]
# ## Display final map
#
# View all detected objects and centroids on the map.

# %%
m
# Out:
# Map(bottom=108974.0, center=[29.379781767454972, -94.64996337890626], controls=(ZoomControl(options=['position…

# %% [markdown]
# ![](https://github.com/user-attachments/assets/032daf91-1cb3-464b-9576-17f61767ab6f)
