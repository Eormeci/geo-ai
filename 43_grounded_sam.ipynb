# %% [markdown]
# # Image Segmentation with Grounded SAM
#
# [![image](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/opengeos/geoai/blob/main/docs/examples/grounded_sam.ipynb)
#
# This notebook demonstrates how to use the `GroundedSAM` class to segment images using Grounded SAM. To learn more about Grounded SAM, please refer to the [Grounded SAM](https://huggingface.co/docs/transformers/model_doc/grounding-dino#grounded-sam) documentation.
#
# ## Install package
#
# To use the `geoai-py` package, ensure it is installed in your environment. Uncomment the command below if needed.

# %%
# %pip install geoai-py

# %% [markdown]
# ## Import library

# %%
import geoai
from geoai.segment import GroundedSAM

# %% [markdown]
# ## Download sample data
#
# The sample data is from [OpenAerialMap](https://map.openaerialmap.org/#/-122.24462628364563,37.54457094085014,18/square/023010230021/60a48baa25820c0005e45906?_k=jqrisj). Credits to the provider Jason McMinn.

# %%
raster_url = "https://huggingface.co/datasets/giswqs/geospatial/resolve/main/aerial.tif"

# %%
raster_path = geoai.download_file(raster_url)
# Out:
# Downloading aerial.tif: 100%|██████████| 42.5M/42.5M [00:01<00:00, 35.3MB/s]

# %% [markdown]
# ## Visualize sample data

# %%
geoai.view_raster(raster_url)
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d5cb76df4177a983fe14e74aa0573a59 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/proj4@2.8.1/dist/proj4.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/georaster@1.6.0&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/georaster-layer-for-leaflet@4.1.2/dist/georaster-layer-for-leaflet.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d5cb76df4177a983fe14e74aa0573a59&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d5cb76df4177a983fe14e74aa0573a59 = L.map(
#                 &quot;map_d5cb76df4177a983fe14e74aa0573a59&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 2,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
#   &quot;drawExport&quot;: false,
#   &quot;layersControl&quot;: true,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_d5cb76df4177a983fe14e74aa0573a59);
#
#
#
#
#
#             var tile_layer_ed1eae71239a3082059afbd76bef2f42 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 24,
#   &quot;maxNativeZoom&quot;: 24,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ed1eae71239a3082059afbd76bef2f42.addTo(map_d5cb76df4177a983fe14e74aa0573a59);
#
#
#             L.control.fullscreen(
#                 {
#   &quot;position&quot;: &quot;topleft&quot;,
#   &quot;title&quot;: &quot;Full Screen&quot;,
#   &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;,
#   &quot;forceSeparateButton&quot;: false,
# }
#             ).addTo(map_d5cb76df4177a983fe14e74aa0573a59);
#
#
#             map_d5cb76df4177a983fe14e74aa0573a59.fitBounds(
#                 [[20, 0], [20, 0]],
#                 {&quot;maxZoom&quot;: 2}
#             );
#
#
#             var macro_element_de519221133f8f93858b12d8d86e07ed = L.layerGroup();
#
#             (function() {
#                 var layerName = &quot;Raster&quot;;
#                 if (true) {
#                     macro_element_de519221133f8f93858b12d8d86e07ed._layerControlName = layerName;
#                     map_d5cb76df4177a983fe14e74aa0573a59.layerControlEntries = map_d5cb76df4177a983fe14e74aa0573a59.layerControlEntries || [];
#                     map_d5cb76df4177a983fe14e74aa0573a59.layerControlEntries.push({ layer: macro_element_de519221133f8f93858b12d8d86e07ed, name: layerName });
#                 }
#             })();
#
#             (async function() {
#                 const waitForGeoRaster = (maxAttempts = 60, delay = 200) =&gt;
#                     new Promise((resolve, reject) =&gt; {
#                         let attempts = 0;
#                         const check = () =&gt; {
#                             if (window.parseGeoraster &amp;&amp; window.GeoRasterLayer) {
#                                 resolve();
#                             } else if (attempts &gt;= maxAttempts) {
#                                 reject(new Error(&quot;GeoRaster libraries failed to load&quot;));
#                             } else {
#                                 attempts += 1;
#                                 setTimeout(check, delay);
#                             }
#                         };
#                         check();
#                     });
#
#                 try {
#                     await waitForGeoRaster();
#                     const mapRef = map_d5cb76df4177a983fe14e74aa0573a59;
#                     const layerSequence = 1;
#
#                     // Create a custom pane for this GeoTIFF layer with explicit z-index
#                     const paneName = &#x27;geotiff-pane-&#x27; + layerSequence;
#                     if (!mapRef.getPane(paneName)) {
#                         const pane = mapRef.createPane(paneName);
#                         // Set z-index: 400 is default for overlays (vectors), use 300-399 range
#                         // for GeoTIFF layers so they appear below vector layers
#                         pane.style.zIndex = 300 + layerSequence;
#                     }
#
#                     const indexes = null;
#                     const georaster = await window.parseGeoraster(&quot;https://huggingface.co/datasets/giswqs/geospatial/resolve/main/aerial.tif&quot;);
#                     const palette = [];
#                     const hasPalette = Array.isArray(palette) &amp;&amp; palette.length &gt; 0;
#                     const nodataColor = null;
#                     const suppliedRange = null;
#                     const layerOptions = {&quot;name&quot;: &quot;Raster&quot;, &quot;opacity&quot;: 1.0, &quot;resolution&quot;: 128, &quot;zIndex&quot;: 501};
#                     layerOptions.georast

# %% [markdown]
# ## Image Segmentation

# %%
grounded_sam = GroundedSAM(
    detector_id="IDEA-Research/grounding-dino-tiny",
    segmenter_id="facebook/sam-vit-base",
    device=None,  # Will auto-detect CUDA if available
    tile_size=1024,
    overlap=128,
    threshold=0.3,
)
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/689M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/990 [00:00<?, ?it/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# added_tokens.json:   0%|          | 0.00/82.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/457 [00:00<?, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/375M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/314 [00:00<?, ?it/s]
# preprocessor_config.json:   0%|          | 0.00/466 [00:00<?, ?B/s]

# %%
text_prompts = ["building", "car", "tree"]
output_file = "segmented_objects.tif"

# %%
result_files = grounded_sam.segment_image(
    input_path=raster_path,
    output_path=output_file,
    text_prompts=text_prompts,
    polygon_refinement=True,
    export_boxes=True,
    export_polygons=True,
    smoothing_sigma=1.0,
    nms_threshold=0.5,
    min_polygon_area=50,
    simplify_tolerance=1.0,
)

# %%
result_files

# %% [markdown]
# ## Visualize results

# %%
polygons = result_files["polygons"]
boxes = result_files["boxes"]

# %%
geoai.view_vector_interactive(
    polygons, basemap=raster_url, column="label", cmap="tab20"
)

# %%
geoai.view_raster(output_file, indexes=[2], basemap=raster_url, layer_name="Building")

# %%
geoai.view_raster(output_file, indexes=[3], basemap=raster_url, layer_name="Car")

# %%
geoai.view_raster(output_file, indexes=[4], basemap=raster_url, layer_name="Tree")
