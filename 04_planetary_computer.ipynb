# %% [markdown]
# # Download Data from Planetary Computer
#
# [![image](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/opengeos/geoai/blob/main/docs/examples/planetary_computer.ipynb)
#
# ## Install package
# To use the `geoai-py` package, ensure it is installed in your environment. Uncomment the command below if needed.

# %%
# %pip install geoai-py

# %% [markdown]
# ## Import libraries

# %%
import geoai

# %% [markdown]
# ## Retrieve collections

# %%
collections = geoai.pc_collection_list()
collections
# Out:
#                            id                                           title  \
# 42  3dep-lidar-classification                  USGS 3DEP Lidar Classification
# 29            3dep-lidar-copc                     USGS 3DEP Lidar Point Cloud
# 3              3dep-lidar-dsm           USGS 3DEP Lidar Digital Surface Model
# 43             3dep-lidar-dtm           USGS 3DEP Lidar Digital Terrain Model
# 41      3dep-lidar-dtm-native  USGS 3DEP Lidar Digital Terrain Model (Native)
# ..                        ...                                             ...
# 15               terraclimate                                    TerraClimate
# 55                  us-census                                       US Census
# 84                   usda-cdl                USDA Cropland Data Layers (CDLs)
# 89       usgs-lcmap-conus-v13                 USGS LCMAP CONUS Collection 1.3
# 90      usgs-lcmap-hawaii-v10                USGS LCMAP Hawaii Collection 1.0
#
#                                           description
# 42  This collection is derived from the [USGS 3DEP...
# 29  This collection contains source data from the ...
# 3   This collection is derived from the [USGS 3DEP...
# 43  This collection is derived from the [USGS 3DEP...
# 41  This collection is derived from the [USGS 3DEP...
# ..                                                ...
# 15  [TerraClimate](http://www.climatologylab.org/t...
# 55  The [2020 Census](https://www.census.gov/progr...
# 84  The Cropland Data Layer (CDL) is a product of ...
# 89  The [Land Change Monitoring, Assessment, and P...
# 90  The [Land Change Monitoring, Assessment, and P...
#
# [135 rows x 3 columns]

# %% [markdown]
# ## Search NAIP imagery

# %%
items = geoai.pc_stac_search(
    collection="naip",
    bbox=[-76.6657, 39.2648, -76.6478, 39.2724],  # Baltimore area
    time_range="2013-01-01/2014-12-31",
)
# Out:
# /home/openzeka/.local/lib/python3.11/site-packages/pystac_client/item_search.py:925: FutureWarning: get_items() is deprecated, use items() instead
#   warnings.warn(

# %%
items
# Out:
# [<Item id=md_m_3907643_se_18_1_20130917_20131112>]

# %% [markdown]
# ## Visualize NAIP imagery

# %%
geoai.pc_item_asset_list(items[0])
# Out:
# ['image', 'metadata', 'thumbnail', 'tilejson', 'rendered_preview']

# %%
geoai.view_pc_item(item=items[0])
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8157aab29690b9b211f75eb70b118381 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8157aab29690b9b211f75eb70b118381&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8157aab29690b9b211f75eb70b118381 = L.map(
#                 &quot;map_8157aab29690b9b211f75eb70b118381&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 2,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
#   &quot;drawControl&quot;: false,
#   &quot;drawExport&quot;: false,
#   &quot;layersControl&quot;: true,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_8157aab29690b9b211f75eb70b118381);
#
#
#
#
#
#             var tile_layer_a3af1c95d1556f478a39375bcdc57e10 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 24,
#   &quot;maxNativeZoom&quot;: 24,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a3af1c95d1556f478a39375bcdc57e10.addTo(map_8157aab29690b9b211f75eb70b118381);
#
#
#             L.control.fullscreen(
#                 {
#   &quot;position&quot;: &quot;topleft&quot;,
#   &quot;title&quot;: &quot;Full Screen&quot;,
#   &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;,
#   &quot;forceSeparateButton&quot;: false,
# }
#             ).addTo(map_8157aab29690b9b211f75eb70b118381);
#
#
#             map_8157aab29690b9b211f75eb70b118381.fitBounds(
#                 [[20, 0], [20, 0]],
#                 {&quot;maxZoom&quot;: 2}
#             );
#
#
#             var tile_layer_d7a6b34edf007880e0d4e63283ae7344 = L.tileLayer(
#                 &quot;https://planetarycomputer.microsoft.com/api/data/v1/item/tiles/WebMercatorQuad/{z}/{x}/{y}@1x?collection=naip\u0026item=md_m_3907643_se_18_1_20130917_20131112\u0026assets=image\u0026rescale=33.0%2C233.0&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 30,
#   &quot;maxNativeZoom&quot;: 30,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Planetary Computer&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1.0,
# }
#
#             );
#
#
#             tile_layer_d7a6b34edf007880e0d4e63283ae7344.addTo(map_8157aab29690b9b211f75eb70b118381);
#
#
#             map_8157aab29690b9b211f75eb70b118381.fitBounds(
#                 [[39.246356663657366, -76.69255279437866], [39.31614422230839, -76.62001566899772]],
#                 {}
#             );
#
#
#             var layer_control_14a91923c7e4ddd2fac289c4472b766f_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_a3af1c95d1556f478a39375bcdc57e10,
#                 },
#                 overlays :  {
#                     &quot;STAC Item&quot; : tile_layer_d7a6b34edf007880e0d4e63283ae7344,
#                 },
#             };
#             let layer_control_14a91923c7e4ddd2fac289c4472b766f = L.control.layers(
#                 layer_control_14a91923c7e4ddd2fac289c4472b766f_layers.base_layers,
#                 layer_control_14a91923c7e4ddd2fac289c4472b766f_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: true,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_8157aab29690b9b211f75eb70b118381);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" width="100%" height="600"style="border:none !important;" "allowfullscreen" "webkitallowfullscreen" "mozallowfullscreen"></iframe>

# %% [markdown]
# ## Download NAIP imagery

# %%
downloaded = geoai.pc_stac_download(
    items, output_dir="data", assets=["image", "thumbnail"]
)
# Out:
# Downloading md_m_3907643_se_18_1_20130917_20131112_image: 100%|██| 176M/176M [00:35<00:00, 5.17MB/s]
# Downloading md_m_3907643_se_18_1_20130917_20131112_thumbnail: 100%|█| 18.6k/18.6k [00:00<00:00, 359k

# %% [markdown]
# ## Search land cover data

# %%
items = geoai.pc_stac_search(
    collection="chesapeake-lc-13",
    bbox=[-76.6657, 39.2648, -76.6478, 39.2724],  # Baltimore area
    time_range="2013-01-01/2014-12-31",
    max_items=10,
)

# %%
items
# Out:
# [<Item id=Baywide_13Class_20132014_E1640000_N1970000>]

# %% [markdown]
# ## Visualize land cover data

# %%
geoai.pc_item_asset_list(items[0])
# Out:
# ['data', 'tilejson', 'rendered_preview']

# %%
geoai.view_pc_item(item=items[0], colormap_name="tab10", basemap="SATELLITE")
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_248bcea6750d6826db0e26b291163165 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_248bcea6750d6826db0e26b291163165&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_248bcea6750d6826db0e26b291163165 = L.map(
#                 &quot;map_248bcea6750d6826db0e26b291163165&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 2,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
#   &quot;drawControl&quot;: false,
#   &quot;drawExport&quot;: false,
#   &quot;layersControl&quot;: true,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_248bcea6750d6826db0e26b291163165);
#
#
#
#
#
#             var tile_layer_6e403e094d939d771b220c69e9198152 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 24,
#   &quot;maxNativeZoom&quot;: 24,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6e403e094d939d771b220c69e9198152.addTo(map_248bcea6750d6826db0e26b291163165);
#
#
#             L.control.fullscreen(
#                 {
#   &quot;position&quot;: &quot;topleft&quot;,
#   &quot;title&quot;: &quot;Full Screen&quot;,
#   &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;,
#   &quot;forceSeparateButton&quot;: false,
# }
#             ).addTo(map_248bcea6750d6826db0e26b291163165);
#
#
#             map_248bcea6750d6826db0e26b291163165.fitBounds(
#                 [[20, 0], [20, 0]],
#                 {&quot;maxZoom&quot;: 2}
#             );
#
#
#             var tile_layer_5c7ac8d822c6eae09b72f042e016075a = L.tileLayer(
#                 &quot;https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 24,
#   &quot;maxNativeZoom&quot;: 24,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Esri&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5c7ac8d822c6eae09b72f042e016075a.addTo(map_248bcea6750d6826db0e26b291163165);
#
#
#             var tile_layer_81969e77a80c1e0bf494dd0fcd977888 = L.tileLayer(
#                 &quot;https://planetarycomputer.microsoft.com/api/data/v1/item/tiles/WebMercatorQuad/{z}/{x}/{y}@1x?colormap_name=tab10\u0026collection=chesapeake-lc-13\u0026item=Baywide_13Class_20132014_E1640000_N1970000\u0026assets=data\u0026rescale=1.0%2C10.0&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 30,
#   &quot;maxNativeZoom&quot;: 30,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Planetary Computer&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1.0,
# }
#
#             );
#
#
#             tile_layer_81969e77a80c1e0bf494dd0fcd977888.addTo(map_248bcea6750d6826db0e26b291163165);
#
#
#             map_248bcea6750d6826db0e26b291163165.fitBounds(
#                 [[39.23068359277666, -76.68798051330445], [39.33613057862134, -76.54970523646796]],
#                 {}
#             );
#
#
#             var layer_control_e05a4f9e14b71d3f2a462652060c7843_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_6e403e094d939d771b220c69e9198152,
#                 },
#                 overlays :  {
#                     &quot;Esri.WorldImagery&quot; : tile_layer_5c7ac8d822c6eae09b72f042e016075a,
#                     &quot;STAC Item&quot; : tile_layer_81969e77a80c1e0bf494dd0fcd977888,
#                 },
#             };
#             let layer_control_e05a4f9e14b71d3f2a462652060c7843 = L.control.layers(
#                 layer_control_e05a4f9e14b71d3f2a462652060c7843_layers.base_layers,
#                 layer_control_e05a4f9e14b71d3f2a462652060c7843_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: true,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_248bcea6750d6826db0e26b291163165);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" width="100%" height="600"style="border:none !important;" "allowfullscreen" "webkitallowfullscreen" "mozallowfullscreen"></iframe>

# %% [markdown]
# ## Download land cover data

# %%
geoai.pc_stac_download(items[0], output_dir="data", assets=["data", "rendered_preview"])
# Out:
# Downloading Baywide_13Class_20132014_E1640000_N1970000_data: 100%|█| 10.7M/10.7M [00:01<00:00, 8.90M
# Downloading Baywide_13Class_20132014_E1640000_N1970000_rendered_preview: 529kB [00:00, 2.51MB/s]
# {'Baywide_13Class_20132014_E1640000_N1970000': {'data': 'data/Baywide_13Class_20132014_E1640000_N1970000_data.tif',
#   'rendered_preview': 'data/Baywide_13Class_20132014_E1640000_N1970000_rendered_preview.png'}}

# %%
ds = geoai.read_pc_item_asset(items[0], asset="data")

# %%
ds
# Out:
# <xarray.DataArray (band: 1, y: 10000, x: 10000)> Size: 100MB
# [100000000 values with dtype=uint8]
# Coordinates:
#   * band         (band) int64 8B 1
#   * y            (y) float64 80kB 1.98e+06 1.98e+06 ... 1.97e+06 1.97e+06
#   * x            (x) float64 80kB 1.64e+06 1.64e+06 ... 1.65e+06 1.65e+06
#     spatial_ref  int64 8B 0
# Attributes:
#     DataType:            Generic
#     AREA_OR_POINT:       Area
#     RepresentationType:  THEMATIC
#     _FillValue:          0
#     scale_factor:        1.0
#     add_offset:          0.0

# %% [markdown]
# ## Search Landsat data

# %%
items = geoai.pc_stac_search(
    collection="landsat-c2-l2",
    bbox=[-76.6657, 39.2648, -76.6478, 39.2724],  # Baltimore area
    time_range="2024-10-27/2024-12-31",
    query={"eo:cloud_cover": {"lt": 1}},
    max_items=10,
)

# %%
items
# Out:
# [<Item id=LC08_L2SP_015033_20241028_02_T1>]

# %% [markdown]
# ## Visualize Landsat data

# %%
geoai.pc_item_asset_list(items[0])
# Out:
# ['qa',
#  'ang',
#  'red',
#  'blue',
#  'drad',
#  'emis',
#  'emsd',
#  'trad',
#  'urad',
#  'atran',
#  'cdist',
#  'green',
#  'nir08',
#  'lwir11',
#  'swir16',
#  'swir22',
#  'coastal',
#  'mtl.txt',
#  'mtl.xml',
#  'mtl.json',
#  'qa_pixel',
#  'qa_radsat',
#  'qa_aerosol',
#  'tilejson',
#  'rendered_preview']

# %%
geoai.view_pc_item(item=items[0], assets=["red", "green", "blue"])
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fe8ab559fc874e264d8c6d0a095245ee {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fe8ab559fc874e264d8c6d0a095245ee&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fe8ab559fc874e264d8c6d0a095245ee = L.map(
#                 &quot;map_fe8ab559fc874e264d8c6d0a095245ee&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 2,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
#   &quot;drawControl&quot;: false,
#   &quot;drawExport&quot;: false,
#   &quot;layersControl&quot;: true,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_fe8ab559fc874e264d8c6d0a095245ee);
#
#
#
#
#
#             var tile_layer_b5a0405c57159bd7a6d5d194c413ffe8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 24,
#   &quot;maxNativeZoom&quot;: 24,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b5a0405c57159bd7a6d5d194c413ffe8.addTo(map_fe8ab559fc874e264d8c6d0a095245ee);
#
#
#             L.control.fullscreen(
#                 {
#   &quot;position&quot;: &quot;topleft&quot;,
#   &quot;title&quot;: &quot;Full Screen&quot;,
#   &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;,
#   &quot;forceSeparateButton&quot;: false,
# }
#             ).addTo(map_fe8ab559fc874e264d8c6d0a095245ee);
#
#
#             map_fe8ab559fc874e264d8c6d0a095245ee.fitBounds(
#                 [[20, 0], [20, 0]],
#                 {&quot;maxZoom&quot;: 2}
#             );
#
#
#             var tile_layer_564c52396d66b188710e1c568d4ffce3 = L.tileLayer(
#                 &quot;https://planetarycomputer.microsoft.com/api/data/v1/item/tiles/WebMercatorQuad/{z}/{x}/{y}@1x?collection=landsat-c2-l2\u0026item=LC08_L2SP_015033_20241028_02_T1\u0026assets=red\u0026assets=green\u0026assets=blue\u0026rescale=7412.0%2C13010.0&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 30,
#   &quot;maxNativeZoom&quot;: 30,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Planetary Computer&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1.0,
# }
#
#             );
#
#
#             tile_layer_564c52396d66b188710e1c568d4ffce3.addTo(map_fe8ab559fc874e264d8c6d0a095245ee);
#
#
#             map_fe8ab559fc874e264d8c6d0a095245ee.fitBounds(
#                 [[37.79650042267936, -78.27150211430529], [39.98763139942484, -75.5067044162279]],
#                 {}
#             );
#
#
#             var layer_control_ed81dd28c16973c17475513b0279b37c_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_b5a0405c57159bd7a6d5d194c413ffe8,
#                 },
#                 overlays :  {
#                     &quot;STAC Item&quot; : tile_layer_564c52396d66b188710e1c568d4ffce3,
#                 },
#             };
#             let layer_control_ed81dd28c16973c17475513b0279b37c = L.control.layers(
#                 layer_control_ed81dd28c16973c17475513b0279b37c_layers.base_layers,
#                 layer_control_ed81dd28c16973c17475513b0279b37c_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: true,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_fe8ab559fc874e264d8c6d0a095245ee);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" width="100%" height="600"style="border:none !important;" "allowfullscreen" "webkitallowfullscreen" "mozallowfullscreen"></iframe>

# %%
geoai.view_pc_item(item=items[0], assets=["nir08", "red", "green"])
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d2eaf0febac167db3ed4c4c453e2ea9c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d2eaf0febac167db3ed4c4c453e2ea9c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d2eaf0febac167db3ed4c4c453e2ea9c = L.map(
#                 &quot;map_d2eaf0febac167db3ed4c4c453e2ea9c&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 2,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
#   &quot;drawControl&quot;: false,
#   &quot;drawExport&quot;: false,
#   &quot;layersControl&quot;: true,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_d2eaf0febac167db3ed4c4c453e2ea9c);
#
#
#
#
#
#             var tile_layer_f735b07dda3c65aa17372d99aefad8a5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 24,
#   &quot;maxNativeZoom&quot;: 24,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f735b07dda3c65aa17372d99aefad8a5.addTo(map_d2eaf0febac167db3ed4c4c453e2ea9c);
#
#
#             L.control.fullscreen(
#                 {
#   &quot;position&quot;: &quot;topleft&quot;,
#   &quot;title&quot;: &quot;Full Screen&quot;,
#   &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;,
#   &quot;forceSeparateButton&quot;: false,
# }
#             ).addTo(map_d2eaf0febac167db3ed4c4c453e2ea9c);
#
#
#             map_d2eaf0febac167db3ed4c4c453e2ea9c.fitBounds(
#                 [[20, 0], [20, 0]],
#                 {&quot;maxZoom&quot;: 2}
#             );
#
#
#             var tile_layer_79b8f511bb52ada58f42b7a43a68c4a7 = L.tileLayer(
#                 &quot;https://planetarycomputer.microsoft.com/api/data/v1/item/tiles/WebMercatorQuad/{z}/{x}/{y}@1x?collection=landsat-c2-l2\u0026item=LC08_L2SP_015033_20241028_02_T1\u0026assets=nir08\u0026assets=red\u0026assets=green\u0026rescale=7213.0%2C19866.0&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 30,
#   &quot;maxNativeZoom&quot;: 30,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Planetary Computer&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1.0,
# }
#
#             );
#
#
#             tile_layer_79b8f511bb52ada58f42b7a43a68c4a7.addTo(map_d2eaf0febac167db3ed4c4c453e2ea9c);
#
#
#             map_d2eaf0febac167db3ed4c4c453e2ea9c.fitBounds(
#                 [[37.79650042267936, -78.27150211430529], [39.98763139942484, -75.5067044162279]],
#                 {}
#             );
#
#
#             var layer_control_d57351fe42dda82c2075de84ab1e8a59_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_f735b07dda3c65aa17372d99aefad8a5,
#                 },
#                 overlays :  {
#                     &quot;STAC Item&quot; : tile_layer_79b8f511bb52ada58f42b7a43a68c4a7,
#                 },
#             };
#             let layer_control_d57351fe42dda82c2075de84ab1e8a59 = L.control.layers(
#                 layer_control_d57351fe42dda82c2075de84ab1e8a59_layers.base_layers,
#                 layer_control_d57351fe42dda82c2075de84ab1e8a59_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: true,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_d2eaf0febac167db3ed4c4c453e2ea9c);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" width="100%" height="600"style="border:none !important;" "allowfullscreen" "webkitallowfullscreen" "mozallowfullscreen"></iframe>

# %%
geoai.view_pc_item(
    item=items[0],
    expression="(nir08-red)/(nir08+red)",
    rescale="-1,1",
    colormap_name="greens",
    name="NDVI Green",
)
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_45f40cf9fbbdabdcbc167f2d743aadee {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_45f40cf9fbbdabdcbc167f2d743aadee&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_45f40cf9fbbdabdcbc167f2d743aadee = L.map(
#                 &quot;map_45f40cf9fbbdabdcbc167f2d743aadee&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 2,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
#   &quot;drawControl&quot;: false,
#   &quot;drawExport&quot;: false,
#   &quot;layersControl&quot;: true,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_45f40cf9fbbdabdcbc167f2d743aadee);
#
#
#
#
#
#             var tile_layer_f13d53c826fd466fc4ee948407d4690f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 24,
#   &quot;maxNativeZoom&quot;: 24,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f13d53c826fd466fc4ee948407d4690f.addTo(map_45f40cf9fbbdabdcbc167f2d743aadee);
#
#
#             L.control.fullscreen(
#                 {
#   &quot;position&quot;: &quot;topleft&quot;,
#   &quot;title&quot;: &quot;Full Screen&quot;,
#   &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;,
#   &quot;forceSeparateButton&quot;: false,
# }
#             ).addTo(map_45f40cf9fbbdabdcbc167f2d743aadee);
#
#
#             map_45f40cf9fbbdabdcbc167f2d743aadee.fitBounds(
#                 [[20, 0], [20, 0]],
#                 {&quot;maxZoom&quot;: 2}
#             );
#
#
#             var tile_layer_07bfcc00e626be83a4ca6acdc40e3b97 = L.tileLayer(
#                 &quot;https://planetarycomputer.microsoft.com/api/data/v1/item/tiles/WebMercatorQuad/{z}/{x}/{y}@1x?expression=%28nir08-red%29%2F%28nir08%2Bred%29\u0026rescale=-1%2C1\u0026colormap_name=greens\u0026collection=landsat-c2-l2\u0026item=LC08_L2SP_015033_20241028_02_T1\u0026asset_as_band=True\u0026assets=qa&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 30,
#   &quot;maxNativeZoom&quot;: 30,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Planetary Computer&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1.0,
# }
#
#             );
#
#
#             tile_layer_07bfcc00e626be83a4ca6acdc40e3b97.addTo(map_45f40cf9fbbdabdcbc167f2d743aadee);
#
#
#             map_45f40cf9fbbdabdcbc167f2d743aadee.fitBounds(
#                 [[37.79650042267936, -78.27150211430529], [39.98763139942484, -75.5067044162279]],
#                 {}
#             );
#
#
#             var layer_control_20894457e45150a33574f1e1c1efe569_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_f13d53c826fd466fc4ee948407d4690f,
#                 },
#                 overlays :  {
#                     &quot;NDVI Green&quot; : tile_layer_07bfcc00e626be83a4ca6acdc40e3b97,
#                 },
#             };
#             let layer_control_20894457e45150a33574f1e1c1efe569 = L.control.layers(
#                 layer_control_20894457e45150a33574f1e1c1efe569_layers.base_layers,
#                 layer_control_20894457e45150a33574f1e1c1efe569_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: true,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_45f40cf9fbbdabdcbc167f2d743aadee);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" width="100%" height="600"style="border:none !important;" "allowfullscreen" "webkitallowfullscreen" "mozallowfullscreen"></iframe>

# %% [markdown]
# ## Download Landsat data

# %%
geoai.pc_stac_download(
    items[0], output_dir="data", assets=["nir08", "red", "green", "blue"]
)
# Out:
# Downloading LC08_L2SP_015033_20241028_02_T1_red: 100%|█████████| 83.9M/83.9M [00:12<00:00, 7.11MB/s]
# Downloading LC08_L2SP_015033_20241028_02_T1_blue: 100%|████████| 79.7M/79.7M [00:10<00:00, 7.99MB/s]
# Downloading LC08_L2SP_015033_20241028_02_T1_green: 100%|███████| 82.3M/82.3M [00:11<00:00, 7.46MB/s]
# Downloading LC08_L2SP_015033_20241028_02_T1_nir08: 100%|███████| 88.9M/88.9M [00:18<00:00, 4.99MB/s]
# {'LC08_L2SP_015033_20241028_02_T1': {'red': 'data/LC08_L2SP_015033_20241028_02_T1_red.tif',
#   'blue': 'data/LC08_L2SP_015033_20241028_02_T1_blue.tif',
#   'green': 'data/LC08_L2SP_015033_20241028_02_T1_green.tif',
#   'nir08': 'data/LC08_L2SP_015033_20241028_02_T1_nir08.tif'}}
